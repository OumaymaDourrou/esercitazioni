# %% [markdown]
# #le funzioni

# %%
def sommaduenum(x,y):
  '''somma delle variabili x,y'''
  ris = x+y
  return ris

# %%
sommaduenum(-150,100)
# Out:
# -50

# %%
def posneg(x):
  if x<0:
    return "il num è neg"
  elif x==0:
    return 'il numero inserito è 0, cambiare num'
  else:
    return'il num è pos'

# %%
posneg(1)
# Out:
# 'il num è pos'

# %%
x = float(input("inserire un numero: "))

if x<0:
    print ("il num è neg")
elif x==0:
    print ('il numero inserito è 0, cambiare num')
else:
    print('il num è pos')
# Out:
# inserire un numero: 8
# il num è pos

# %% [markdown]
# ##pari dispari con la formula

# %%
def pari(x):
  if x%2 == 0:
    return'il num è pari'
  else:
    return'il num è dispari'

# %%
pari(5)
# Out:
# 'il num è dispari'

# %% [markdown]
# ##pari dispari senza formula con metodo input

# %%
x=int(input("inserire un numero: "))
if x%2 == 0:
  print("il numero è pari")
else:
  print("il num è dispari")
# Out:
# inserire un numero: 5
# il num è dispari

# %% [markdown]
# #area triangolo

# %%
# %%writefile formulario.py

def areatriangolo(b,h):
  area= b*h/2
  return area

# %%
areatriangolo(20,5)
# Out:
# 50.0

# %% [markdown]
# ##per creare un file paythom per poter importare le formule come delle librerie
# writing formulario.py

# %%
# %%writefile formulario.py

def areatriangolo(b,h):
  area= b*h/2
  return area
# Out:
# Writing formulario.py

# %%
from formulario import areatriangolo as at

# %%
at(4,7)
# Out:
# 14.0

# %%
# %%writefile formulario2.py

def pari(x):
  if x%2 == 0:
    return'il num è pari'
  else:
    return'il num è dispari'
# Out:
# Writing formulario2.py

# %%
pari(100)
# Out:
# 'il num è pari'

# %%
pari(200)
# Out:
# ('il num è pari', 260.0)

# %%
def perimetrotriangolo(a, b, c):
  perimetro= a + b + c
  return perimetro

# %%
perimetrotriangolo(14, 15, 12)
# Out:
# 41

# %%
from formulario import perimetrotriangolo as pt

# %%
pt(5,6,8)
# Out:
# 19

# %%
# %%writefile formulario.py
def perimetrotriangolo(a, b, c):
  perimetro= a + b + c
  return perimetro
# Out:
# Overwriting formulario.py
